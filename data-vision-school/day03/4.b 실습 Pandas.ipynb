# %% [markdown]
# winemag-data-130k-v2.csv 파일을 reviews 로 읽는다.

# %%
import pandas as pd
reviews = pd.read_csv('winemag-data_first150k.csv', index_col=0)
reviews
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# ...                                      ...     ...    ...
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province           region_1           region_2  \
# 0               California        Napa Valley               Napa
# 1           Northern Spain               Toro                NaN
# 2               California     Knights Valley             Sonoma
# 3                   Oregon  Willamette Valley  Willamette Valley
# 4                 Provence             Bandol                NaN
# ...                    ...                ...                ...
# 150925      Southern Italy  Fiano di Avellino                NaN
# 150926           Champagne          Champagne                NaN
# 150927      Southern Italy  Fiano di Avellino                NaN
# 150928           Champagne          Champagne                NaN
# 150929  Northeastern Italy         Alto Adige                NaN
#
#                    variety                   winery
# 0       Cabernet Sauvignon                    Heitz
# 1            Tinta de Toro  Bodega Carmen Rodríguez
# 2          Sauvignon Blanc                 Macauley
# 3               Pinot Noir                    Ponzi
# 4       Provence red blend     Domaine de la Bégude
# ...                    ...                      ...
# 150925         White Blend    Feudi di San Gregorio
# 150926     Champagne Blend                H.Germain
# 150927         White Blend                Terredora
# 150928     Champagne Blend                   Gosset
# 150929        Pinot Grigio            Alois Lageder
#
# [150930 rows x 10 columns]

# %% [markdown]
# 리뷰의 디스크립션 컬럼을 desc 로 저장한다.

# %%
desc = reviews['description']

# %% [markdown]
# first_description 이라는 변수에는, 디스크립션 컬럼의 첫번째 데이터를 저장한다.

# %%
first_description = desc[0]
# == reviews['descripition'][0] 과 같음
first_description
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
reviews.loc[ 0, 'description']  # == 같은 결과
# Out:
# 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.'

# %%
reviews.head(1) #숫자만큼 row를 불러온다
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
#
#          designation  points  price    province     region_1 region_2  \
# 0  Martha's Vineyard      96  235.0  California  Napa Valley     Napa
#
#               variety winery
# 0  Cabernet Sauvignon  Heitz

# %% [markdown]
# first_row 라는 변수에, 첫번째 리뷰 데이터(행)를 저장한다.

# %%
first_row = reviews.iloc [0, ]
first_row
# Out:
# country                                                       US
# description    This tremendous 100% varietal wine hails from ...
# designation                                    Martha's Vineyard
# points                                                        96
# price                                                        235
# province                                              California
# region_1                                             Napa Valley
# region_2                                                    Napa
# variety                                       Cabernet Sauvignon
# winery                                                     Heitz
# Name: 0, dtype: object

# %% [markdown]
# 리뷰의 description column 의 값들 중, 첫번째부터 10번째 데이터까지를 first_descriptions 변수에 저장한다.

# %%
first_descriptions = desc[0:10+1]
first_descriptions
# == reviews.loc['description'][0:9+1] 같다. 
# == reviews.loc[0:9, 'description']
# Out:
# 0     This tremendous 100% varietal wine hails from ...
# 1     Ripe aromas of fig, blackberry and cassis are ...
# 2     Mac Watson honors the memory of a wine once ma...
# 3     This spent 20 months in 30% new French oak, an...
# 4     This is the top wine from La Bégude, named aft...
# 5     Deep, dense and pure from the opening bell, th...
# 6     Slightly gritty black-fruit aromas include a s...
# 7     Lush cedary black-fruit aromas are luxe and of...
# 8     This re-named vineyard was formerly bottled as...
# 9     The producer sources from two blocks of the vi...
# 10    Elegance, complexity and structure come togeth...
# Name: description, dtype: object

# %% [markdown]
# 리뷰에서 인덱스가 1, 2, 3, 5, 8 인 데이터를,  sample_reviews 변수에 저장한다.

# %%
#여기에서 인덱스는 사람용 인덱스를 말함 (.loc() )
sample_reviews =reviews.loc[[1, 2, 3, 5, 8] , ]
sample_reviews
# Out:
#   country                                        description  \
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 5   Spain  Deep, dense and pure from the opening bell, th...
# 8      US  This re-named vineyard was formerly bottled as...
#
#                             designation  points  price        province  \
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 5                             Numanthia      95   73.0  Northern Spain
# 8                                Silice      95   65.0          Oregon
#
#              region_1           region_2          variety  \
# 1                Toro                NaN    Tinta de Toro
# 2      Knights Valley             Sonoma  Sauvignon Blanc
# 3   Willamette Valley  Willamette Valley       Pinot Noir
# 5                Toro                NaN    Tinta de Toro
# 8  Chehalem Mountains  Willamette Valley       Pinot Noir
#
#                     winery
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 5                Numanthia
# 8                Bergström

# %% [markdown]
# df 라는 변수에, 다음 조건을 만족하는 데이터프레임을 저장하시오.
# 인덱스가 0, 1, 10, 100 인 데이터에서, 컬럼이 country, province, region_1, region_2 인 데이터들만 가져와서 저장하시오.

# %%
reviews.loc[ [0, 1, 10, 100],]
reviews.loc[:, ['country', 'province', 'region_1', 'region_2']]

df = reviews.loc[ [0, 1, 10, 100], ['country', 'province', 'region_1', 'region_2']]

# %% [markdown]
# Italy 에서 만들어진 와인에 대해서 italian_wines 이라는 이름으로 데이터프레임을 만드시오.

# %%
#reveiws[italian_wines] 
reviews.loc[ reviews['country'] == 'Italy', ]
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# 32           Vigna Piaggia      90    NaN             Tuscany
# 35                 Riserva      90  135.0             Tuscany
# 37                     NaN      90   29.0             Tuscany
# 38                     NaN      90   23.0             Tuscany
# ...                    ...     ...    ...                 ...
# 150920        Brut Riserva      91   19.0  Northeastern Italy
# 150922           Superiore      91    NaN  Northeastern Italy
# 150925                 NaN      91   20.0      Southern Italy
# 150927       Terre di Dora      91   20.0      Southern Italy
# 150929                 NaN      90   15.0  Northeastern Italy
#
#                             region_1 region_2          variety  \
# 10                            Collio      NaN         Friulano
# 32            Brunello di Montalcino      NaN       Sangiovese
# 35            Brunello di Montalcino      NaN       Sangiovese
# 37      Vino Nobile di Montepulciano      NaN       Sangiovese
# 38                  Chianti Classico      NaN       Sangiovese
# ...                              ...      ...              ...
# 150920                        Trento      NaN  Champagne Blend
# 150922    Colli Orientali del Friuli      NaN            Tocai
# 150925             Fiano di Avellino      NaN      White Blend
# 150927             Fiano di Avellino      NaN      White Blend
# 150929                    Alto Adige      NaN     Pinot Grigio
#
#                        winery
# 10           Borgo del Tiglio
# 32            Abbadia Ardenga
# 35                   Carillon
# 37                 Avignonesi
# 38           Casina di Cornia
# ...                       ...
# 150920                Letrari
# 150922      Ronchi di Manzano
# 150925  Feudi di San Gregorio
# 150927              Terredora
# 150929          Alois Lageder
#
# [23478 rows x 10 columns]

# %%
italian_wines = reviews.loc[ reviews['country'] == 'Italy', ]
italian_wines
# Out:
#        country                                        description  \
# 10       Italy  Elegance, complexity and structure come togeth...
# 32       Italy  Underbrush, scorched earth, menthol and plum s...
# 35       Italy  Forest floor, tilled soil, mature berry and a ...
# 37       Italy  Aromas of forest floor, violet, red berry and ...
# 38       Italy  This has a charming nose that boasts rose, vio...
# ...        ...                                                ...
# 150920   Italy  Rich and mature aromas of smoke, earth and her...
# 150922   Italy  Made by 30-ish Roberta Borghese high above Man...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                designation  points  price            province  \
# 10      Ronco della Chiesa      95   80.0  Northeastern Italy
# 32           Vigna Piaggia      90    NaN             Tuscany
# 35                 Riserva      90  135.0             Tuscany
# 37                     NaN      90   29.0             Tuscany
# 38                     NaN      90   23.0             Tuscany
# ...                    ...     ...    ...                 ...
# 150920        Brut Riserva      91   19.0  Northeastern Italy
# 150922           Superiore      91    NaN  Northeastern Italy
# 150925                 NaN      91   20.0      Southern Italy
# 150927       Terre di Dora      91   20.0      Southern Italy
# 150929                 NaN      90   15.0  Northeastern Italy
#
#                             region_1 region_2          variety  \
# 10                            Collio      NaN         Friulano
# 32            Brunello di Montalcino      NaN       Sangiovese
# 35            Brunello di Montalcino      NaN       Sangiovese
# 37      Vino Nobile di Montepulciano      NaN       Sangiovese
# 38                  Chianti Classico      NaN       Sangiovese
# ...                              ...      ...              ...
# 150920                        Trento      NaN  Champagne Blend
# 150922    Colli Orientali del Friuli      NaN            Tocai
# 150925             Fiano di Avellino      NaN      White Blend
# 150927             Fiano di Avellino      NaN      White Blend
# 150929                    Alto Adige      NaN     Pinot Grigio
#
#                        winery
# 10           Borgo del Tiglio
# 32            Abbadia Ardenga
# 35                   Carillon
# 37                 Avignonesi
# 38           Casina di Cornia
# ...                       ...
# 150920                Letrari
# 150922      Ronchi di Manzano
# 150925  Feudi di San Gregorio
# 150927              Terredora
# 150929          Alois Lageder
#
# [23478 rows x 10 columns]

# %% [markdown]
# 리뷰점수가 95점 이상이고, Australia와 New Zealand 에서 만들어진 와인에 대한 데이터프레임을 top_oceania_wines 이라는 이름의 변수로 저장.

# %%
# 한줄로 표시해주고 싶을 때는 마지막에 \ 를 넣어준다

reviews['country'] == "Australia" \
reviews['country'] == "New Zealand"
reviews['points'] >= 95
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: country, Length: 150930, dtype: bool

# %%
reviews['country'] == 'New Zealand'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: country, Length: 150930, dtype: bool

# %%
oceania_wines = (reviews['points'] >= 95) & ((reviews['country'] == "Australia") | (reviews['country'] == 'New Zealand'))

# %%
top_oceania_wines = reviews.loc[ oceania_wines, ]

# %%
top_oceania_wines
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# 2148                      The Factor      98  125.0  South Australia
# 2458                       The Peake      96  150.0  South Australia
# 3033                         Bin 707      95  500.0  South Australia
# 3044        Mount Edelstone Vineyard      95  200.0  South Australia
# 3047                             One      95   95.0  South Australia
# ...                              ...     ...    ...              ...
# 122779  The Standish Single Vineyard      96  135.0  South Australia
# 127614                 Hill of Grace      95  625.0  South Australia
# 137383                      Astralis      95  225.0  South Australia
# 150562                        Grange      96  185.0  South Australia
# 150563                           RWT      95   70.0  South Australia
#
#                region_1 region_2             variety           winery
# 2148     Barossa Valley      NaN              Shiraz         Torbreck
# 2458       McLaren Vale      NaN     Cabernet-Shiraz     Hickinbotham
# 3033    South Australia      NaN  Cabernet Sauvignon         Penfolds
# 3044        Eden Valley      NaN              Shiraz         Henschke
# 3047    Langhorne Creek      NaN           Red Blend        Heartland
# ...                 ...      ...                 ...              ...
# 122779   Barossa Valley      NaN              Shiraz         Standish
# 127614      Eden Valley      NaN              Shiraz         Henschke
# 137383        Clarendon      NaN               Syrah  Clarendon Hills
# 150562  South Australia      NaN              Shiraz         Penfolds
# 150563   Barossa Valley      NaN              Shiraz         Penfolds
#
# [82 rows x 10 columns]

# %%
reviews.loc[ reviews['country'] == 'New Zealand', ]
# Out:
#             country                                        description  \
# 25      New Zealand  Yields were down in 2015, but intensity is up,...
# 305     New Zealand  Yields were down in 2015, but intensity is up,...
# 1171    New Zealand  Usually the bigger, more opulent of the Kumeu ...
# 1184    New Zealand  Envoy is Spy Valley's top range of bottlings. ...
# 1185    New Zealand  This wine shows a fine balance between sweetne...
# ...             ...                                                ...
# 150368  New Zealand  On the vegetal side, with fresh green bean and...
# 150377  New Zealand  Light and a bit herbal, like a pleasant St.-Jo...
# 150378  New Zealand  Impressive purple color, but less intense on t...
# 150382  New Zealand  Features classic Marlborough aromas, marrying ...
# 150389  New Zealand  Aromas of peach and pineapple give way to trop...
#
#                    designation  points  price       province region_1  \
# 25             Maté's Vineyard      94   57.0          Kumeu      NaN
# 305            Maté's Vineyard      94   57.0          Kumeu      NaN
# 1171                Coddington      93   46.0          Kumeu      NaN
# 1184    Envoy Johnson Vineyard      93   33.0    Marlborough      NaN
# 1185               Bannockburn      93   40.0  Central Otago      NaN
# ...                        ...     ...    ...            ...      ...
# 150368                     NaN      84   12.0    Marlborough      NaN
# 150377                Matheson      84    NaN    Hawke's Bay      NaN
# 150378                     NaN      84    NaN  Martinborough      NaN
# 150382                     NaN      84   16.0    Marlborough      NaN
# 150389                     NaN      84   13.0    Marlborough      NaN
#
#        region_2          variety            winery
# 25          NaN       Chardonnay       Kumeu River
# 305         NaN       Chardonnay       Kumeu River
# 1171        NaN       Chardonnay       Kumeu River
# 1184        NaN  Sauvignon Blanc        Spy Valley
# 1185        NaN         Riesling       Felton Road
# ...         ...              ...               ...
# 150368      NaN  Sauvignon Blanc  Southbank Estate
# 150377      NaN            Syrah      Matua Valley
# 150378      NaN            Syrah            Kusuda
# 150382      NaN  Sauvignon Blanc       Saint Clair
# 150389      NaN  Sauvignon Blanc            Babich
#
# [3320 rows x 10 columns]

# %%
# isin() 함수
# 해당 컬럼에 해당 문자열이 있는지 확인, 해당문자열은 2개 이상일 때는 역시 []리스트화 해서 넣기
# 'Mango' in lists 와 같은 식
# 있으면 True, 없으면 False

reviews['country'].isin( ['Australia', 'New Zealand'] )
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 150925    False
# 150926    False
# 150927    False
# 150928    False
# 150929    False
# Name: country, Length: 150930, dtype: bool

# %%
# isin() 활용해서 같은 방식으로 데이터 뽑아오기

# %%
reviews.loc[ (reviews['points'] >= 95) & reviews['country'].isin( ['Australia', 'New Zealand'], ) ]
# Out:
#           country                                        description  \
# 2148    Australia  Full-bodied and plush yet vibrant and imbued w...
# 2458    Australia  This is a top example of the classic Australia...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 3044    Australia  From vines planted in 1912, this has been an i...
# 3047    Australia  This is a throwback to those brash, flavor-exu...
# ...           ...                                                ...
# 122779  Australia  If Standish's Relic is the feminine side of Sh...
# 127614  Australia  This stellar wine takes a little time in the g...
# 137383  Australia  The 2007 Astralis impresses for its combinatio...
# 150562  Australia  As unevolved as they are, the dense and multil...
# 150563  Australia  Seamless luxury from stem to stern, this ‘baby...
#
#                          designation  points  price         province  \
# 2148                      The Factor      98  125.0  South Australia
# 2458                       The Peake      96  150.0  South Australia
# 3033                         Bin 707      95  500.0  South Australia
# 3044        Mount Edelstone Vineyard      95  200.0  South Australia
# 3047                             One      95   95.0  South Australia
# ...                              ...     ...    ...              ...
# 122779  The Standish Single Vineyard      96  135.0  South Australia
# 127614                 Hill of Grace      95  625.0  South Australia
# 137383                      Astralis      95  225.0  South Australia
# 150562                        Grange      96  185.0  South Australia
# 150563                           RWT      95   70.0  South Australia
#
#                region_1 region_2             variety           winery
# 2148     Barossa Valley      NaN              Shiraz         Torbreck
# 2458       McLaren Vale      NaN     Cabernet-Shiraz     Hickinbotham
# 3033    South Australia      NaN  Cabernet Sauvignon         Penfolds
# 3044        Eden Valley      NaN              Shiraz         Henschke
# 3047    Langhorne Creek      NaN           Red Blend        Heartland
# ...                 ...      ...                 ...              ...
# 122779   Barossa Valley      NaN              Shiraz         Standish
# 127614      Eden Valley      NaN              Shiraz         Henschke
# 137383        Clarendon      NaN               Syrah  Clarendon Hills
# 150562  South Australia      NaN              Shiraz         Penfolds
# 150563   Barossa Valley      NaN              Shiraz         Penfolds
#
# [82 rows x 10 columns]
