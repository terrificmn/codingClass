# %% [markdown]
# winemag-data.csv 파일을 reviews 로 읽는다.

# %%
import pandas as pd

# %%
#reviews
reviews = pd.read_csv('winemag-data.csv', index_col = 0)

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %%
reviews['price'].max()
# Out:
# 3300.0

# %%
# 포도주 price 중에 가장 비싼 포도주를 가져와라
reviews.loc[ reviews['price'] == reviews['price'].max() ]
# Out:
#       country                                        description designation  \
# 80290  France  This ripe wine shows plenty of blackberry frui...         NaN
#
#        points   price  province region_1 region_2 taster_name  \
# 80290      88  3300.0  Bordeaux    Médoc      NaN  Roger Voss
#
#       taster_twitter_handle                                 title  \
# 80290            @vossroger  Château les Ormes Sorbet 2013  Médoc
#
#                         variety                    winery
# 80290  Bordeaux-style Red Blend  Château les Ormes Sorbet

# %%
reviews.sort_values(by='price')
# Out:
#          country                                        description  \
# 20484         US  Fruity, soft and rather sweet, this wine smell...
# 112919     Spain  Nice on the nose, this has a leafy note and a ...
# 59507         US  Sweet and fruity, this canned wine feels soft ...
# 31530         US  Packaged in a cute yellow recyclable Tetrapak,...
# 61768      Spain  This opens with standard cherry and berry arom...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price    province  \
# 20484                            NaN      85    4.0  California
# ...

# %%
#점수가 100점 짜리를 찾아서 points 가격순으로 정렬하기
point_100 = reviews.loc[ reviews['points'] == 100, ]

# %%
point_100.sort_values(by='price')
# Out:
#           country                                        description  \
# 123545         US  Initially a rather subdued Frog; as if it has ...
# 113929         US  In 2005 Charles Smith introduced three high-en...
# 58352      France  This is a magnificently solid wine, initially ...
# 45798          US  Tasted in a flight of great and famous Napa wi...
# 7335        Italy  Thick as molasses and dark as caramelized brow...
# 89728      France  This latest incarnation of the famous brand is...
# 36528      France  This is a fabulous wine from the greatest Cham...
# 111754      Italy  It takes only a few moments before you appreci...
# 345     Australia  This wine contains some material over 100 year...
# 111756     France  A hugely powerful wine, full of dark, brooding...
# 42197    Portugal  This is the latest release of what has long be...
# 118058         US  This wine dazzles with perfection. Sourced fro...
# 39286       Italy  A perfect wine from a classic vintage, the 200...
# ...

# %%
# NaN 데이터 확인
reviews.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %% [markdown]
# 인덱스를 title 컬럼으로 셋팅한다.

# %%
# inplace 파라미터로 True로 바로 적용시키기
reviews.set_index('title', inplace=True)
# 또는 reviews = 에 다시 할당한다
# 다시 되돌리는 함수는 reset_index()

# %%
reviews.head()
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)        US
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)  Tart and snappy, the flavors of lime flesh and...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
# Rainstorm 2013 Pinot Gris (Willamette Valley)           NaN      87   14.0
#
# ...

# %% [markdown]
# 먼저 데이터가 비어있느것이 있는지 확인한다.

# %%
reviews.isna().sum()
# Out:
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# variety                      1
# winery                       0
# critic                       0
# dtype: int64

# %% [markdown]
# 그리고나서, 가격이 없는 데이터는 빼고, 데이터셋을 가져온다.

# %%
#reviews['price'].dropna(axis = 0) 
#이렇게 하면 데이터셋은 가져올 수 없고, 가격이 NaN인 것들이 제거된다

# %%
#notna() 함수를 썼으므로, notna이면 True가 되서 notna가 아닌 것들만 가져오게 됨
reviews.loc[ reviews['price'].notna(), ]
# Out:
#                                                      country  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# Tandem 2011 Ars In Vitro Tempranillo-Merlot (Na...     Spain
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...

# %% [markdown]
# 리뷰에 새로운 컬럼 critic 만들고, everyone 이라고 값 넣는다.

# %%
# 컬럼보기 
# columns 속성 이용
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle',
#        'variety', 'winery', 'critic'],
#       dtype='object')

# %%
reviews['critic'] = 'everyone'

# %%
reviews
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)             US
# St. Julian 2013 Reserve Late Harvest Riesling (...        US
# Sweet Cheeks 2012 Vintner's Reserve Wild Child ...        US
# ...                                                      ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...   Germany
# Citation 2004 Pinot Noir (Oregon)                         US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)    France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)         France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...    France
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# ...

# %% [markdown]
# 리뷰의 포인트 컬럼은 수치로 되어있다. 이 컬럼의 기초통계데이터를 확인하시오. (평균, 최대 최소 등)

# %%
reviews['points'].describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %% [markdown]
# 점수를 100점 맞은 와인의 데이터를 가져오시오.

# %%
reviews.loc [ reviews['points'] == 100, ]
# Out:
#                                                       country  \
# title
# Chambers Rosewood Vineyards NV Rare Muscat (Rut...  Australia
# Avignonesi 1995 Occhio di Pernice  (Vin Santo d...      Italy
# Krug 2002 Brut  (Champagne)                            France
# Tenuta dell'Ornellaia 2007 Masseto Merlot (Tosc...      Italy
# Casa Ferreirinha 2008 Barca-Velha Red (Douro)        Portugal
# Biondi Santi 2010 Riserva  (Brunello di Montalc...      Italy
# Cardinale 2006 Cabernet Sauvignon (Napa Valley)            US
# Château Léoville Barton 2010  Saint-Julien             France
# Louis Roederer 2008 Cristal Vintage Brut  (Cham...     France
# Salon 2006 Le Mesnil Blanc de Blancs Brut Chard...     France
# Château Lafite Rothschild 2010  Pauillac               France
# Casanova di Neri 2007 Cerretalto  (Brunello di ...      Italy
# Château Cheval Blanc 2010  Saint-Émilion               France
# Château Léoville Las Cases 2010  Saint-Julien          France
# ...

# %%
reviews.loc [ reviews['points'] == 100, ].shape
# Out:
# (19, 13)

# %%
# 100점 이상의 와인들 중 와인의 이름만 가져오기 
reviews.loc [ reviews['points'] == 100, ]
# Out:
#   File "<ipython-input-84-f27c2565123b>", line 2
#     reviews.loc [ [reviews['points'] == 100 'title'] , ]
#                                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# taster_name 컬럼은 사람 이름으로 되어있다. 몇명의 사람들이 평가를 한것인까?

# %%
reviews['taster_name'].describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
# 19명이 평가 (unique 수치로 알 수 있음)

# %% [markdown]
# 리뷰 포인트의 평균을 구하시오

# %%
reviews['points'].mean()
# Out:
# 88.44713820775404

# %% [markdown]
# 테스터들의 이름을 전부 확인하시오

# %%
reviews['taster_name'].unique()
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews['taster_name'].describe()
# unique 항목 중에서 
# top항목은 가장 많이 나온 사람
# freq는 25514번 나옴
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %% [markdown]
# 각 테스터들은, 각각 몇개의 와인을 테스트 했는지 확인하시오. ( 테스터 이름, 갯수 )

# %%
#value_counts() 는 'taster_name' 컬럼의 unique 를 찾아서  카운트를 해준다, 정렬도 해줌
reviews['taster_name'].value_counts()
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %%
# 그룹화 하기
reviews.groupby('taster_name')

# %%
# 그룹화 한 후에 taster_name의 count()를 해주면 됨
reviews.groupby('taster_name')['taster_name'].count()
# Out:
# taster_name
# Alexander Peartree      415
# Anna Lee C. Iijima     4415
# Anne Krebiehl MW       3685
# Carrie Dykes            139
# Christina Pickard         6
# Fiona Adams              27
# Jeff Jenssen            491
# Jim Gordon             4177
# Joe Czerwinski         5147
# Kerin O’Keefe         10776
# Lauren Buzzeo          1835
# Matt Kettmann          6332
# Michael Schachner     15134
# Mike DeSimone           514
# Paul Gregutt           9532
# Roger Voss            25514
# Sean P. Sullivan       4966
# Susan Kostrzewa        1085
# Virginie Boone         9537
# Name: taster_name, dtype: int64

# %%
#정렬하기 , 위의 방법과 같은 방법
reviews.groupby('taster_name')['taster_name'].count().sort_values(ascending=False)
# Out:
# taster_name
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %% [markdown]
# 리뷰의 포인트의 평균을 구하고, 리뷰의 포인트값이, 평균보다 큰 데이터 (즉, 평가가 좋은 와인) 만 가져오시오.

# %%
reviews.loc[ reviews['points'] > reviews['points'].mean(), ]
# Out:
#                                                       country  \
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...     France
# Ceretto 2003 Bricco Rocche Prapó  (Barolo)              Italy
# Matrix 2007 Stuhlmuller Vineyard Chardonnay (Al...         US
# Mauritson 2007 Rockpile Cemetary Vineyard Zinfa...         US
# Henry's Drive Vignerons 2006 Parson's Flat Shir...  Australia
# ...                                                       ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 B...    Germany
# Citation 2004 Pinot Noir (Oregon)                          US
# Domaine Gresser 2013 Kritt Gewurztraminer (Alsace)     France
# Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          France
# Domaine Schoffit 2012 Lieu-dit Harth Cuvée Caro...     France
#
#                                                                                           description  \
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vend...  Medium-gold in color. Complex and inviting nos...
# ...

# %%
reviews.loc[ reviews['points'] > reviews['points'].mean(),  ].sort_values(by='price')
# Out:
#                                                      country  \
# title
# Hogue 2008 Red Table Wine Red (Columbia Valley ...        US
# Borsao 2008 Monte Oton Garnacha (Campo de Borja)       Spain
# Herdade dos Machados 2012 Toutalga Red (Alentej...  Portugal
# Caves Velhas 2013 D. Fuas Reserva Red (Terras d...  Portugal
# Woodbridge by Robert Mondavi 2015 Pinot Noir (C...        US
# ...                                                      ...
# Simone Scaletta 2007 Chirlet  (Barolo)                 Italy
# Quinta da Pacheca 2013 Pacheca Superior Red (Do...  Portugal
# Seacampo 2011 Reserva Red (Dão)                     Portugal
# Le Mandolare 2015 Corte Menini  (Soave Classico)       Italy
# Domaine Ehrhart 2013 Domaine Saint-Rémy Herrenw...    France
#
#                                                                                           description  \
# title
# Hogue 2008 Red Table Wine Red (Columbia Valley ...  Tart and juicy, this Cabernet/Merlot/Syrah ble...
# ...

# %%
#에러 원인 찾아보기  현재 'title'이 row index로 되어 있어서 그런 듯 함
# ['title', 'price'] 하면 에러 남

reviews.loc[reviews['points'] > reviews['points'].mean() , 'price']
# Out:
# title
# Dopff & Irion 2004 Schoenenbourg Grand Cru Vendanges Tardives Riesling (Alsace)                          80.0
# Ceretto 2003 Bricco Rocche Prapó  (Barolo)                                                               70.0
# Matrix 2007 Stuhlmuller Vineyard Chardonnay (Alexander Valley)                                           36.0
# Mauritson 2007 Rockpile Cemetary Vineyard Zinfandel (Rockpile)                                           39.0
# Henry's Drive Vignerons 2006 Parson's Flat Shiraz-Cabernet Sauvignon (Padthaway)                         40.0
#                                                                                                          ...
# Dr. H. Thanisch (Erben Müller-Burggraef) 2013 Brauneberger Juffer-Sonnenuhr Spätlese Riesling (Mosel)    28.0
# Citation 2004 Pinot Noir (Oregon)                                                                        75.0
# ...
