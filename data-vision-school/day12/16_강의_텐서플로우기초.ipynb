# %% [markdown]
# # The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# 다음과 같은 식을 찾아내는 딥러닝을 만들어 보자
#
# y = (2 * x) - 1
#
#
# ```
# float hw_function(float x){
#     float y = (2 * x) - 1;
#     return y;
# }
# ```

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# tensorflow 묘듈을 설치하려면 pip install tensorflow를 해야함
# google에서 만든 tensorflow가 가장 유명
# 2번째로 유명한 것은 facebook에서 만든.. PyTorch

# %% [markdown]
# ## Define and Compile the Neural Network
#
# 1개의 레이어, 그리고 1개의 뉴런을 가지고 있는 뉴럴 네트워크 모델링 하기

# %%
tf.keras.Sequential( [keras.layers.Dense(units=1, input_shape = [1])] )

# %% [markdown]
# input layer - hidden layer - output layer로 구성되는 것을 Sequential 이라고 함
# Dense는 한 레이어 구성을 말하고, units=1 은 뉴런이 하나,  그 안의 input_shape = [1]는 일차원으로 되어 있음

# %%
model = tf.keras.Sequential( [keras.layers.Dense(units=1, input_shape = [1])] )

# %% [markdown]
# 컴파일 하기 위해서는 2개의 함수가 필요하다.
#
# loss 와 optimizer.
#
# 학습을 통해 예측한 값과, 실제의 y=10x+10 값 두개를 측정하는 LOSS function 을 설정해야 한다.
#
# 위의 로스를 최소화 하기 위해서 OPTIMIZER function 을 설정한다.
#
# 로스펑션으로 'MEAN SQUARED ERROR'를 사용하고, 옵티마이저로 'STOCHASTIC GRADIENT DESCENT' 를 사용한다. 아직 수학적으로 알 필요는 없다.
# ( 교재 78)

# %%
# optimizer='sgd'는 STOCHASTIC GRADIENT DESCENT
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data
#
# y=2x-1 이 식에 따라, x의 데이터 6개와, 그에 해당하는 y의 데이터 6개를 준비한다. 머신러닝은 데이터로부터 학습하는 것이기 때문이다. 이 데이터로부터 우리는 위의 식을 컴퓨터가 찾아내도록 하는것이다.
#
# 'Numpy' 라이브러리를 이용해서, xs 와 ys 를 만든다. 각각 6개씩

# %%
xs = np.array( [-1.0, 0.0, 1.0, 2.0, 3.0, 4.0] , dtype=float )

# %%
ys = np.array( [ -3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float )
# 정답지

# %%
# 위의 xs, ys를 가지고 컴퓨터가 학습해서

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# x와 y의 관계를 찾기 위해서, 학습하는 함수인 **model.fit** 함수를 호출한다. 각 에포크별로 좋은 모델인지 아닌지 평가할 수 있는 loss 값을 제공한다.

# %%
# epoches=
# 위의 있는 데이터를 xs를 10번 반복하겠다. w값은 계속 바뀌므로 오차가 줄어든다
model.fit(xs, ys, epochs=500)

# loss: 오차값 오차값이 줄어드는것을 알 수 있능
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6200
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5963
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5754
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5567
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5399
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5246
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5105
# Epoch 8/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4974
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4851
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4735
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4625
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4520
# ...

# %% [markdown]
# 모델의 학습이 끝나면 이제 **model.predict** 함수를 이용해서 새로운 데이터를 예측할 수 있다. 10을 넣어보자. 무슨 값이 예측되었는가?

# %%
model.predict( [10.0])
# 처음에는 15.79나옴
# y = 2x - 1  ==> x가 10이면, y는 19 근처로 나와야 성능좋은 인공지능

# epochs=500으로 다시 한 다음에 다시 학습시키면
# 19에 가까운 수가 나옴. 18.98
# Out:
# array([[18.987661]], dtype=float32)

# %% [markdown]
# 19가 정확히 나오지 않은 이유는, 뉴럴넷은 확률로 처리한다. 따라서 주어진 데이터 6개를 보고, 식이 Y=2X-1 과 비슷할 것이라고 예측한 것이다. 그래서 거의 19라고 예측을 해준다.
