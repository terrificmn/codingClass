# %% [markdown]
# ## Exercise 3
# 손글씨 숫자 MNIST 를 가지고, 99.8% accuracy 보다 크게 나오도록,  convolutional layer 는 딱 1개만 사용하고,  MaxPooling 2D도 한 1개만 사용한다.
#
# 그리고 epochs는 20으로 셋팅하고,  accuracy 가 위의 수치를 만족하면, "Reached 99.8% accuracy so cancelling training!"를 출력하고, 학습을 멈추도록 모델링과 컴파일을 하시오.

# %%
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
  mnist = tf.keras.datasets.mnist
  (training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# %%
training_images.shape
# Out:
# (60000, 28, 28)

# %%
# Out:
# (60000, 28, 28, 1)

# %%
def train_mnist_conv():
    # myCallback class
  class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
      i = 0.998
      if (logs.get('accuracy') > i ):
        print("\n정확도 {}%가 되어서 학습을 종료합니다".format(i*100))  
        self.model.stop_training = True
    
  myCallback = myCallback()
   
  mnist = tf.keras.datasets.mnist
  (training_images, training_labels), (test_images, test_labels) = mnist.load_data()

  training_images = training_images.reshape(60000 , 28, 28, 1)
  test_images = test_images.reshape(10000 , 28, 28, 1)
  
  training_images = training_images / 255.0
  test_images = test_images / 255.0

  model = tf.keras.models.Sequential([
    Conv2D( filters = 64, kernel_size=(3, 3), activation='relu', input_shape= (28, 28, 1) ),
    MaxPooling2D( 2, 2 ),
    Flatten(),
    Dense( units=256, activation='relu'),
    Dense( units=512, activation='relu'), 
    Dense( units=10, activation='softmax')
    
  ])

  model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    # model fitting
  history = model.fit(
    training_images, training_labels, epochs=20, validation_split=0.25, callbacks=[ myCallback ]
  )
  # model fitting
  return history.epoch, history.history['accuracy'][-1]

# %%
hist_epoch, hist_accuracy = train_mnist_conv()
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 66s 46ms/step - loss: 0.3044 - accuracy: 0.9035 - val_loss: 0.0796 - val_accuracy: 0.9762
# Epoch 2/20
# 1407/1407 [==============================] - 67s 48ms/step - loss: 0.0486 - accuracy: 0.9851 - val_loss: 0.0571 - val_accuracy: 0.9827
# Epoch 3/20
# 1407/1407 [==============================] - 67s 48ms/step - loss: 0.0259 - accuracy: 0.9924 - val_loss: 0.0671 - val_accuracy: 0.9821
# Epoch 4/20
# 1407/1407 [==============================] - 65s 46ms/step - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.0664 - val_accuracy: 0.9841
# Epoch 5/20
# 1407/1407 [==============================] - 66s 47ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0651 - val_accuracy: 0.9851
# Epoch 6/20
# 1407/1407 [==============================] - 67s 48ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0644 - val_accuracy: 0.9837
# Epoch 7/20
# 1407/1407 [==============================] - 66s 47ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0759 - val_accuracy: 0.9832
# Epoch 8/20
# 1407/1407 [==============================] - 66s 47ms/step - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.0849 - val_accuracy: 0.9837
# Epoch 9/20
# 1407/1407 [==============================] - 66s 47ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0760 - val_accuracy: 0.9857
# Epoch 10/20
# 1407/1407 [==============================] - 64s 45ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0967 - val_accuracy: 0.9828
#
# 정확도 99.8%가 되어서 학습을 종료합니다
